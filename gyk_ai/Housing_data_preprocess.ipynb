# %% [markdown]
# ### Ödev
#
# Boston housting dataseti ML'e hazır hale getir.
#
# Pandas ile görüntüle, analiz et
# Eksik verileri doldur
#
# Analiz ve veri doldurma işlemlerinden sonra csv olarak kaydet.
# https://www.kaggle.com/datasets/altavish/boston-housing-dataset
#
# verilerde görüntülemek istediğiniz 2 senaryo seçip 2 adet grafik oluşturunuz. (age ile fiyat eğrisi)
#
# ### Opsiyonel
#
# pandas yerine veri doldurma için scikitlearn kütüphanesinde alternatifler varsa kullanabilirsin.

# %%
import pandas as pd

# %%
df = pd.read_csv("HousingData.csv")

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.shape
# Out:
# (506, 14)

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
df["CRIM"].mean()
# Out:
# 3.6118739711934156

# %%
df["CRIM"].max()
# Out:
# 88.9762

# %%
df["CRIM"] = df["CRIM"].fillna(df["CRIM"].mean())

# %%
df.isnull().sum()
# Out:
# CRIM        0
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %% [markdown]
# ##### ZN

# %%
df["ZN"].mean()
# Out:
# 11.2119341563786

# %%
df["ZN"] = df["ZN"].fillna(df["ZN"].mean())

# %%
df.isnull().sum()
# Out:
# CRIM        0
# ZN          0
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %% [markdown]
# ###### INDUS

# %%
df["INDUS"] = df["INDUS"].fillna(df["INDUS"].mean())

# %%
df.isnull().sum()
# Out:
# CRIM        0
# ZN          0
# INDUS       0
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %% [markdown]
# ###### CHAS

# %%
df.tail(50)
# Out:
#           CRIM         ZN      INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 456   4.668830   0.000000  18.100000   0.0  0.713  5.976  87.9  2.5806   24
# 457   8.200580   0.000000  18.100000   0.0  0.713  5.936  80.3  2.7792   24
# 458   7.752230  11.211934  11.083992   0.0  0.713  6.301  83.7  2.7831   24
# 459   6.801170   0.000000  18.100000   0.0  0.713  6.081  84.4  2.7175   24
# 460   3.611874   0.000000  18.100000   0.0  0.713  6.701  90.0  2.5975   24
# 461   3.693110   0.000000  18.100000   0.0  0.713  6.376  88.4  2.5671   24
# 462   6.654920   0.000000  18.100000   0.0  0.713  6.317  83.0  2.7344   24
# 463   5.821150   0.000000  18.100000   0.0  0.713  6.513  89.9  2.8016   24
# 464   7.839320   0.000000  18.100000   0.0  0.655  6.209  65.4  2.9634   24
# 465   3.611874   0.000000  18.100000   NaN  0.655  5.759  48.2  3.0665   24
# 466   3.774980   0.000000  11.083992   0.0  0.655  5.952  84.7  2.8715   24
# ...

# %%
df["CHAS"] = df["CHAS"].fillna(0)

# %%
df.isnull().sum()
# Out:
# CRIM        0
# ZN          0
# INDUS       0
# CHAS        0
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df["AGE"] = df["AGE"].fillna(df["AGE"].mean())

# %%
df.isnull().sum()
# Out:
# CRIM        0
# ZN          0
# INDUS       0
# CHAS        0
# NOX         0
# RM          0
# AGE         0
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df["LSTAT"] = df["LSTAT"].fillna(df["LSTAT"].mean())

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.to_csv("housing_data_fillna.csv")
